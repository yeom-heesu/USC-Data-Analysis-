# %% [markdown]
# # Yeom heesu.

# %%
#nltk.download('stopwords')
#import wordcloud
import pandas as pd
import csv
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import pandas as pd
import matplotlib.pyplot as plt
import numpy
import matplotlib.pyplot as plt
import operator
from collections import OrderedDict
import re

# %%
def clean_tweet(tweet):
    '''
    Utility function to clean tweet text by removing links, special characters using simple regex statements.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])| (\w +:\ / \ / \S +)", " ", tweet).split())

# %% [markdown]
# ## pre-treatment

# %%
final_dictionary = {}
with open('GoodDoctorWeek1_clean.csv',encoding="UTF-8") as csv_file:
    csv_reader = csv.reader(csv_file,delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            line_count = line_count + 1
            
        else:
            txt = row[0]
            txt = clean_tweet(txt)
            final_txt = txt.lower()
            stop_words = set(stopwords.words('english'))
            tokenizer = RegexpTokenizer(r'\w+')
            word_tokens = tokenizer.tokenize(final_txt)
            filtered_sentence = [w for w in word_tokens if not w in stop_words]
            for w in filtered_sentence:
                if w not in final_dictionary:
                    final_dictionary[w] = 1
                else:
                    final_dictionary[w] = final_dictionary[w] + 1
                    
    line_count = line_count +1
# Out:
# ['Text', 'Time Zone', 'Timestamp', 'Y-M-D-H(PST)', 'Year', 'Month', 'Day', 'Hour']
# ['rt @jwthfc:  gooddoctor เวอร์ชั่นอเมริกันรีเมคจะฉายตอนแรก 25 ก.ย.นี้ ช่อง abc https://t.co/witpylxx7i  주원  joowon  굿닥터…', 'Pacific Time (US & Canada)', '1.51E+12', '2017-09-23-08', '2017', '9', '23', '8']
# ['‘ thegooddoctor’:  tamlyntomita upped to series regular on  abc drama  gooddoctor  berlinstation...… https://t.co/7wyrung6ry', 'None', '1.51E+12', '2017-09-23-08', '2017', '9', '23', '8']
# ['‘ thegooddoctor’:  tamlyntomita upped to series regular on  abc drama  gooddoctor  berlinstation...… https://t.co/ksr6clfakf', 'None', '1.51E+12', '2017-09-23-08', '2017', '9', '23', '8']
# ['the journey begins - the good doctor (pls rt↺❤️) https://t.co/uj7stbikp4  gooddoctor  trailer  thegooddoctor  television  s', 'Pacific Time (US & Canada)', '1.51E+12', '2017-09-23-09', '2017', '9', '23', '9']
# ...

# %%
sorted_d = sorted(final_dictionary.items(),key=operator.itemgetter(1),reverse=True)
print (sorted_d)
# Out:
# [('rt', 16158), ('thegooddoctor', 15582), ('https', 15194), ('doctor', 13999), ('good', 13300), ('co', 12988), ('tonight', 6604), ('10', 6128), ('freddie', 5978), ('highmore', 5834), ('9c', 5193), ('abc', 5032), ('premieres', 4061), ('shaun', 3835), ('murphy', 3548), ('dr', 3380), ('d9eda5e5ft', 2816), ('show', 2266), ('come', 2177), ('greatest', 2099), ('sometimes', 2084), ('c', 2075), ('premiere', 2069), ('dwts', 2042), ('anywhere', 2015), ('heroes', 2003), ('like', 1908), ('watch', 1803), ('watching', 1535), ('extraordinary', 1497), ('save', 1379), ('lives', 1378), ('new', 1354), ('rkeogmdlxe', 1281), ('2qlue5gs1i', 1138), ('young', 1085), ('series', 1039), ('see', 1028), ('premiering', 980), ('de', 969), ('amp', 939), ('tomorrow', 932), ('excited', 927), ('love', 861), ('9', 765), ('already', 714), ('monday', 710), ('episode', 642), ('man', 641), ('autism', 636), ('tv', 623), ('amazing', 595), ('bates', 580), ('think', 574), ('mind', 556), ('drama', 544), ('wait', 543), ('drag', 
# ...

# %%
df = pd.DataFrame(sorted_d)
df.columns = ['Word','Frequency']
df
#df.plot(kind='bar')
# Out:
#                 Word  Frequency
# 0                 rt      16158
# 1      thegooddoctor      15582
# 2              https      15194
# 3             doctor      13999
# 4               good      13300
# 5                 co      12988
# 6            tonight       6604
# 7                 10       6128
# 8            freddie       5978
# 9           highmore       5834
# 10                9c       5193
# 11               abc       5032
# 12         premieres       4061
# 13             shaun       3835
# 14            murphy       3548
# 15                dr       3380
# 16        d9eda5e5ft       2816
# 17              show       2266
# 18              come       2177
# 19          greatest       2099
# 20         sometimes       2084
# 21                 c       2075
# 22          premiere       2069
# 23              dwts       2042
# 24          anywhere       2015
# 25            heroes       2003
# 26              like       1908
# 27             watch       1803
# ...

# %% [markdown]
# ### Showing plot

# %%
plt.bar(df['Word'][:10],df['Frequency'][:10])
plt.xticks(rotation=90)
plt.show()

# %%
df_gd = pd.read_csv('GoodDoctorWeek1_clean.csv')

# %%
df_gd['Day'].value_counts()
# Out:
# 25.0    18932
# 26.0     3550
# 23.0     3331
# 24.0     2195
# 27.0      983
# 28.0      264
# Name: Day, dtype: int64

# %% [markdown]
# ### Day by frequency pie

# %%
plt.pie(list(df_gd['Day'].value_counts()),
        labels=['25day','26day','23day','24day','27day','28day'])
plt.show()

# %%
labels = df_gd['Time Zone'].value_counts()[1:6].to_frame().reset_index()['index']

# %%
# Out:
# 0    Pacific Time (US & Canada)
# 1    Eastern Time (US & Canada)
# 2    Central Time (US & Canada)
# 3                      Brasilia
# 4                       Bangkok
# Name: index, dtype: object

# %%
plt.pie(list(df_gd['Time Zone'].value_counts()[1:6]),labels=labels,colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0'])
plt.show()
