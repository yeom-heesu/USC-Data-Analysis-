# %%
import re
from textblob import TextBlob

# %% [markdown]
# If you get an error such as "No module named 'nltk'", you need to download the following package.
# >> pip install nltk
#
# If you get an error such as "No module named 'textblob'", you need to download the following package.
# >> pip install textblob

# %%
def clean_tweet(tweet):
    '''
    Utility function to clean tweet text by removing links, special characters
    using simple regex statements.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])| (\w +:\ / \ / \S +)", " ", tweet).split())

# %%
def get_tweet_sentiment(tweet):
    '''
        Utility function to classify sentiment of passed tweet
        using textblob's sentiment method
        '''
        # create TextBlob object of passed tweet text
    analysis = TextBlob(clean_tweet(tweet))
        # set sentiment
    if analysis.sentiment.polarity > 0:
        return analysis.sentiment.polarity
    elif analysis.sentiment.polarity == 0:
        return analysis.sentiment.polarity
    else:
        return analysis.sentiment.polarity

# %%
count = 0
f_input= open("C:/Users/Abdullah/Documents/Summer2019CourseNoteBooks/tweet_input.csv",encoding="utf8")
f_output= open("C:/Users/Abdullah/Documents/Summer2019CourseNoteBooks/nltk_output.txt","w",encoding="utf8")

lines = [x.strip() for x in f_input.readlines()]
for line in lines:
    count+=1
    
    #first line is a headerline. Skip intentionally.
    if count == 1:    
        continue
    
    lineTokens = line.split(',')
    sent = str(get_tweet_sentiment(lineTokens[0]))
    print(lineTokens[0] + "\t" + sent)
    f_output.write(lineTokens[0] + "\t" + sent + "\n")

f_output.close()
f_input.close()
# Out:
# walking these streets like it's still a summer night ðŸŽ‰	0.0
# The view from above #viewfromabove #nofilter @ Fairmont San Francisco http://t.co/f9wqdUSs39	0.0
# Ayyye http://t.co/JyffQ9j6hg	0.0
# @jacksfilms #jackask why Is that piece of dog shit on ur face. No I just kid. Ind	-0.2
# These flashbacks are killing me	0.0
# That's the shit I do like... feeling safe and protected. ðŸ˜ðŸ˜ðŸ˜	0.15
# @BCLA09 Helluva game.	-0.4
# @drewwww since when did you join @twitch?	0.0
# "When a pill bottle says ""avoid alcoholic beverages"" what they are REALLY saying is ""drink to enhance"""	-0.024999999999999994
# @brisenthh yesterday night I think you should see him before he leaves. He's leaving for 3 years he's ganna be in Maryland	0.0
# ðŸ’ #vote5sos	0.0
# @trvpunzel what is even happening in that emoji... haha	0.2
# I should be turnt up with @alwaysveronica_	0.0
# ...
